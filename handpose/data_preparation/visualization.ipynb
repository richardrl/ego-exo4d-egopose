# %% [markdown]
# ### [Hand] Ego Pose Visualization
#
# In this notebook you can visualize the hand ego pose annotation. Please make sure you have followed instructions in README.md to get the ground truth JSON file and undistorted Aria images. Some notes about directories to be used:
#
# - `<egoexo_output_dir>`: Directory of the data downloaded by Ego-Exo4D Downloader.
# - `<gt_output_dir>`: Output directory of hand ego pose data preparation script.

# %% [markdown]
# #### Setup

# %%
import cv2
import json
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from utils.utils import get_ego_aria_cam_name, cam_to_img

# %%
egoexo_output_dir = "/data/pulkitag/models/rli14/data/egoexo" # MODIFY
gt_output_dir = "/data/pulkitag/models/rli14/data/egoexo_hand_gen" # MODIFY

# Choose split and annotation type
split = "train"  # MODIFY
anno_type = "manual"    # MODIFY
orientation = "portrait" # MODIFY

assert split in ["train", "val", "test"], f"Invalid split: {split}"
assert anno_type in ["manual", "auto"], f"Invalid anno_type: {anno_type}"
assert orientation in ["landscape", "portrait"], f"Invalid orientation: {orientation}"

# %%
# Load in train split ground truth annotation
if split in ["train", "val"]:
    gt_anno_path = os.path.join(gt_output_dir, f"annotations/{anno_type}/ego_pose_gt_anno_{split}_public.json")
else:
    gt_anno_path = os.path.join(gt_output_dir, f"annotations/{anno_type}/ego_pose_gt_anno_{split}_private.json")
assert os.path.exists(gt_anno_path), f"{gt_anno_path} doesn't exist"
gt_anno = json.load(open(gt_anno_path))

# Load in takes metadata
takes = json.load(open(os.path.join(egoexo_output_dir, "takes.json")))

# camera pose and parameters
cam_pose_dir = os.path.join(egoexo_output_dir, f"annotations/ego_pose/{split}/camera_pose")

# Undistorted Aria image directory
img_view_prefix = "image_portrait_view" if orientation == "portrait" else "image"
img_dir = os.path.join(gt_output_dir, f"{img_view_prefix}/undistorted/{split}")

# take uid dict
take_to_uid = {each_take['take_name'] : each_take['take_uid'] for each_take in takes if each_take["take_uid"] in gt_anno.keys()}
uid_to_take = {uid:take for take, uid in take_to_uid.items()}

# Helper function for visualization
def vis_2d_bbox(img, two_hands_bbox, take_name, frame_idx, label=""):
    assert isinstance(two_hands_bbox, dict) and len(two_hands_bbox) == 2

    ## Plot
    plt.figure(figsize=(5,5))
    plt.imshow(img)
    for _, one_hand_bbox in two_hands_bbox.items():
        if len(one_hand_bbox) > 0:
            plt.plot([one_hand_bbox[0],one_hand_bbox[2]], [one_hand_bbox[1],one_hand_bbox[1]], 'r')
            plt.plot([one_hand_bbox[0],one_hand_bbox[0]], [one_hand_bbox[1],one_hand_bbox[3]], 'r')
            plt.plot([one_hand_bbox[0],one_hand_bbox[2]], [one_hand_bbox[3],one_hand_bbox[3]], 'r')
            plt.plot([one_hand_bbox[2],one_hand_bbox[2]], [one_hand_bbox[1],one_hand_bbox[3]], 'r')
    plt.title(f"{label} {take_name} - frame_idx={frame_idx}", fontsize=10)
    plt.axis("off")

def vis_2d_hand_pose(img, two_hand_kpts_2d, take_name, frame_idx, label=""):
    ## Vis index misc ###
    finger_index = np.array([[0,1,2,3,4],
                             [0,5,6,7,8],
                             [0,9,10,11,12],
                             [0,13,14,15,16],
                             [0,17,18,19,20]])
    color_dict = {0:'tab:blue', 1:'tab:orange', 2:'tab:green', 3:'tab:red', 4:'tab:purple'}
    assert isinstance(two_hand_kpts_2d, dict) and len(two_hand_kpts_2d) == 2

    ## Plot
    plt.figure(figsize=(5,5))
    plt.imshow(img)
    for _, one_hand_kpts_2d in two_hand_kpts_2d.items():
        if len(one_hand_kpts_2d) > 0:
            for i, each_finger_index in enumerate(finger_index):
                curr_finger_kpts = one_hand_kpts_2d[each_finger_index]
                plt.plot(curr_finger_kpts[:,0], curr_finger_kpts[:,1], marker='o', markersize=2, color=color_dict[i])
    plt.title(f"{label} {take_name} - frame_idx={frame_idx}", fontsize=10)
    plt.axis("off")


def vis_3d_hand_pose(two_hand_kpts_3d):
    ## Vis index misc ###
    finger_index = np.array([[0,1,2,3,4],
                             [0,5,6,7,8],
                             [0,9,10,11,12],
                             [0,13,14,15,16],
                             [0,17,18,19,20]])
    color_dict = {0:'tab:blue', 1:'tab:orange', 2:'tab:green', 3:'tab:red', 4:'tab:purple'}
    assert isinstance(two_hand_kpts_3d, dict) and len(two_hand_kpts_3d) == 2

    fig = plt.figure(figsize=plt.figaspect(0.5))
    for i, hand_order in enumerate(["left", "right"]):
        one_hand_kpts_3d = two_hand_kpts_3d[hand_order]
        ax = fig.add_subplot(1, 2, i+1, projection='3d')
        ax.set_title(f"3D plot - {hand_order} hand")
        if len(one_hand_kpts_3d) > 0:
            for f_ith, each_finger_index in enumerate(finger_index):
                curr_finger_kpts = one_hand_kpts_3d[each_finger_index]
                ax.scatter(curr_finger_kpts[:,0], curr_finger_kpts[:,1], curr_finger_kpts[:,2], color=color_dict[f_ith])
                ax.plot3D(curr_finger_kpts[:,0], curr_finger_kpts[:,1], curr_finger_kpts[:,2], color=color_dict[f_ith])
            ax.set_xlabel("X")
            ax.set_ylabel("Y")
            ax.set_zlabel("Z")
        ax.set_aspect('equal')

# %% [markdown]
# #### Select takes

# %%
print(f"Found {len(gt_anno)} takes from {split} split:")
for uid in gt_anno:
    print(f"{uid_to_take[uid]:25s} {uid}")
# Out:
# Found 248 takes from train split:
# fair_bike_06_14           75c8af15-2c63-4024-ab24-db3ec0569207
# fair_bike_02_12           74a85d9d-234c-40f8-b15d-03f222a4db19
# sfu_covid_001_6           1831d594-72a4-42ba-9828-177bfb8b6e21
# iiith_piano_001_4         9baa6a3d-0767-45d6-923a-fd4e85a69911
# georgiatech_bike_09_8     f830b550-8282-4e37-8417-5fe5d094f0fc
# georgiatech_covid_09_10   11bf68ee-12f0-435d-98eb-925c158ac705
# georgiatech_bike_04_4     e24f2e2d-bc8f-4039-b617-b48bc45659bb
# iiith_cooking_79_2        281b1c72-71be-4745-9a21-3a24a02e3c6f
# upenn_0721_Piano_2_5      23ff1c48-01ea-4d34-a38b-bc96e767b9b9
# cmu_bike16_2              6ba1dc31-7a08-4e92-aaad-5954bce6a7da
# upenn_0726_Piano_1_2      b016b093-27d8-4507-84d3-1905141bd715
# fair_bike_07_20           8ee798db-d02b-46ab-86f9-2091da1fb85e
# fair_bike_07_6            ae8c1f26-ae3c-4df9-841c-ee364f0e4fc6
# georgiatech_bike_03_11    6671ef2a-d949-4452-8241-b8db11490d99
# sfu_covid_001_8           0cf0130a-2eed-49a9-8f66-8440e3aa387d
# cmu_bike09_5              111c8b18-f7da-4613-8821-98b5ca61eaf5
# cmu_bike02_2              95c23366-4418-4760-951d-085f1e07df19
# nus_cooking_06_5          d1888843-9fb6-4a0b-a732-978d03786ae6
# iiith_cooking_142_2       e68d09a0-fe18-483c-8a7d-24b32f9baa9e
# georgiatech_covid_05_4    bbc13004-11f9-4a73-ab06-3fa3836d518f
# indiana_bike_06_5         35e43599-f438-4bc9-8983-68cecaf330e8
# iiith_cooking_108_2       adf67490-c9f0-4771-810a-3c6b4007b3c8
# cmu_bike13_4              ff22eeaa-b5e4-48f7-8a48-50bb368ec289
# iiith_cooking_116_4       77e3b40d-7693-49f1-b480-d33fd798f870
# cmu_bike19_3              1b8601c0-ca65-4b4a-9ed4-0248d9539257
# iiith_cooking_122_2       a9902d89-3aab-4bce-aa07-720cf12523f6
# upenn_0709_Guitar_1_2     373478a3-4b72-44f9-bcda-fea08828c52a
# fair_bike_06_12           aef08b40-a12b-42e8-b69a-9ba14c270b7c
# cmu_bike20_4              2e53bfbb-2476-48c8-8dbb-668071453cc2
# upenn_0407_Guitar_1_2     dc3e63c1-5b14-46f3-8230-5c93249e9469
# sfu_covid_010_4           d9c3ae49-4650-40fe-b734-3b2097cf4eed
# cmu_bike20_2              45199fd8-dfda-446d-b1c3-f5e4deadc441
# fair_bike_07_7            08abcbb4-9277-4154-94d8-9e36b750fed8
# iiith_cooking_99_4        4e251499-d729-4861-9ffd-b852f28e2334
# cmu_bike20_3              87a63705-c609-49cd-9605-0117ad0b0526
# indiana_music_06_2        70222fce-427f-45d8-9587-08cc315869fc
# fair_bike_07_11           43dcdaaf-746e-4665-88a3-adbe7351c9b1
# fair_bike_07_16           dcc39981-04fc-4dfc-9bc4-53699496af39
# sfu_covid_001_12          09399c5a-e4fc-4f7b-a1b1-550f2203db44
# upenn_0717_Piano_3_2      77d985cb-eff9-43ca-b5e2-e2d1433d0d4b
# fair_bike_02_11           aaea78b8-f839-42af-af65-0cc3f7fb2897
# fair_bike_01_8            e246e05c-cc49-4d05-98ba-de2542e42c3f
# iiith_cooking_130_2       847fbeab-dd68-4852-95f3-3a09f754f3b7
# cmu_bike01_2              ed3ec638-8363-4e1d-9851-c7936cbfad8c
# fair_cooking_08_8         407f60e4-68b2-42df-84a9-3160398aaf10
# iiith_cooking_84_2        769c8fe5-3f64-4b55-894b-8e6b7e8aa683
# upenn_0722_Violin_1_2     4bb9382b-ca84-4635-9626-f4aa949747f5
# georgiatech_bike_01_11    4abc4d07-a180-4713-b507-69c2fe7f2db8
# georgiatech_covid_05_10   5ab8958c-7f0f-4580-8de4-edd20a839c49
# georgiatech_bike_02_8     80b5ba89-1f51-4f2a-9c68-116122b0a62e
# fair_bike_07_2            2a160c63-2acd-463a-8431-3dbf77d6de8e
# nus_cpr_25_2              58004f8a-fd60-4db6-8145-5125a4cd346f
# utokyo_pcr_2001_37_6      bdd39e2f-019a-4acd-8c50-86d8831a2a9e
# cmu_bike01_7              6f942bbd-acc8-4ec1-8758-89029b391cda
# georgiatech_covid_09_8    1bd5a43c-9476-4491-b82e-6b02aeee2231
# georgiatech_bike_08_10    4314405a-618d-40e4-830f-ab9c23211588
# iiith_guitar_002_4        527abbcb-0144-418a-9096-1ca2de8f26f0
# utokyo_pcr_2001_37_2      e4d26f73-845c-4ec0-a0cf-2610c29680f8
# georgiatech_bike_05_6     73935c70-6d88-4f4d-a4f3-9baf70afa5b1
# georgiatech_covid_09_2    d0109704-c19c-444a-890f-5796742434a8
# iiith_cooking_57_4        1c504968-4f68-48dc-bee3-159fa197af65
# fair_bike_07_12           cda6c810-63a5-455e-b92c-f288e26c72e1
# georgiatech_bike_03_5     e57ffcd1-425a-484d-9ea2-0c073134ce31
# upenn_0317_Violin_3_10    cd8c9e3b-92ca-4e68-9f6d-d8bfb6904045
# utokyo_pcr_2001_38_2      919edc15-276e-4a76-ace9-b01eec04d94b
# georgiatech_bike_03_2     ec944f9c-2cd6-4f7d-9883-0bebb1feb0f7
# georgiatech_bike_02_6     c5df9b0f-2bb2-4283-9483-32395296e0da
# indiana_bike_06_4         7afe02e8-fbde-42fe-9d1b-1663cb6e0f7d
# upenn_0317_Violin_3_7     5957bdc7-1d39-497e-877d-aff0846ed8d4
# cmu_bike16_4              dd23d126-e63d-4df0-ba1e-2c0c137d5bb2
# iiith_cooking_97_2        ff8cba46-32f2-41fc-a649-50ef32fa245c
# indiana_bike_06_9         6ee5fd43-9000-4b49-80e5-4c7b628dbe44
# indiana_bike_06_11        5462ea13-4e33-4c14-9f7c-fbf7756a95c9
# georgiatech_covid_05_8    d8a7872e-aa42-4296-a4b8-53b72f3c8b19
# georgiatech_bike_09_2     d57e2e2d-2da4-4a67-8312-60b9ca0551c6
# sfu_covid_010_2           c8aabd02-b46e-4e91-b2f4-f9d97cfb1a75
# sfu_covid_013_12          3dd860a1-8e01-4a44-9382-fc8ffab5834e
# cmu_bike03_4              ff468baf-2313-4b39-8dc3-a1d1b6f71a5d
# georgiatech_covid_09_12   6dd93969-2dff-4546-bac6-a435698eb14a
# georgiatech_covid_09_6    f7919017-3bd3-4c92-8f7f-ce9b33f07353
# fair_bike_06_4            8ad67099-9fd2-40aa-868c-3c458d238dbb
# upenn_0331_Guitar_2_5     864edaa2-694f-45d7-8519-65f3e819d585
# iiith_cooking_78_2        3a634852-7746-44d8-ad5c-b0d15e961ebb
# georgiatech_covid_03_14   2a926404-4a2f-49a7-b249-7cbd16f1235e
# upenn_0722_Piano_2_3      efacaa24-2dd2-45f2-a316-414f2e2cddc6
# georgiatech_bike_03_12    87512275-0774-4ae1-84e8-6258f67577f7
# iiith_cooking_57_2        dd0539a4-6c12-4ae9-987b-d41351d874a9
# fair_bike_06_20           516e461f-d51a-459f-9cfa-8864bda4c06e
# indiana_music_12_3        1f4c44e1-4190-41ed-bb5e-4bb8c1dd4339
# uniandes_cooking_006_4    ab4b4145-563f-42f9-bfb6-97b48bdaa2c7
# georgiatech_bike_11_5     1d3caeb8-3450-46b7-b341-092ca8fd6beb
# georgiatech_bike_18_12    563ce5eb-88cf-4ffd-9840-d50f122dd596
# fair_bike_01_12           6ec6a770-8e10-4cae-a06b-328852838ec6
# fair_bike_07_10           181c0eb5-22da-4a00-ad59-37b67622012e
# iiith_cooking_41_1        8a81ba3d-61f4-4b6b-a0a3-e1463a226985
# georgiatech_covid_03_8    612b8008-e028-4fcc-a6dc-4a5ee3115e6d
# nus_cpr_08_2              9bd3f0f1-531c-47e1-be1c-2b4eae001bd5
# georgiatech_bike_01_6     16ead1fe-e652-4b14-9c5d-2d73abd5ba78
# utokyo_pcr_2001_35_2      fed78491-6136-4377-aac2-cba3e9bcd4ce
# cmu_bike16_3              98c6b563-61dd-46fd-a66e-351664092e4c
# iiith_cooking_41_3        a914f836-eb7d-4ebc-a537-e8d7dbb39429
# fair_bike_01_10           526fb4ce-d45c-40e9-912b-7cc076081d65
# georgiatech_bike_03_3     b73c9ebb-ad50-4a32-b5ff-137d0684e365
# cmu_bike01_4              27de9577-b69b-441c-9a6f-63d286a9a640
# iiith_piano_001_2         f0fd5cca-ad0c-466e-86a0-342055f99431
# fair_bike_01_2            02715c86-e30c-4791-92b7-38b488e51aba
# georgiatech_covid_12_3    062ed386-05a4-4ff5-a8ff-2235045349d7
# georgiatech_bike_18_8     ca360201-f003-44c5-ab2b-2487cdec5e1a
# georgiatech_bike_04_6     919b7ecf-b37e-4dd2-9fac-4f04b80fbeb8
# upenn_0722_Violin_1_3     0bc47e29-e086-4726-b874-f89671366f06
# georgiatech_covid_14_7    b19462f1-e7fa-4b90-83da-931b1e9d50e2
# iiith_cooking_12_1        be1eb1c1-a45f-4e8b-9ae2-3d8db0af7e59
# georgiatech_bike_04_12    b7542f4c-19e9-4061-87be-5a6d3d95de88
# georgiatech_bike_02_11    ad4bbbb2-2371-4b6a-8645-4c1e4016f00d
# iiith_cooking_124_2       3655a8a0-38fc-4be9-ab20-32448b48abb1
# cmu_bike01_5              d8013909-d1be-4b97-831e-b903115eb94c
# cmu_bike14_2              15b70076-fe8e-4e72-a2cf-0004798c7280
# utokyo_pcr_2001_37_4      4c9f0e2c-9c40-468e-beec-9173683d6b0c
# georgiatech_covid_05_2    c8b331da-1756-4836-acc5-f3d1c2142339
# georgiatech_covid_07_6    77cd56fc-6b68-4c7f-814b-81545484dd2d
# georgiatech_bike_03_10    8172c572-08c7-4fd1-8ab5-114efc84a5ef
# upenn_0331_Guitar_4_3     586d90de-ac05-4262-89e0-292b8b315f39
# upenn_0407_Violin_1_3     f6368758-2a5b-4332-b7b0-deec2f5b080d
# georgiatech_bike_05_4     4031a0f2-7819-402a-9f7c-9b66e14cb366
# cmu_bike19_4              a91ef958-df79-4905-8469-37c552c11441
# iiith_cooking_80_2        5795a690-ce90-4c46-81ec-3959cb1d0027
# georgiatech_covid_16_12   0266d30c-c751-451b-9425-a1c1b19cbac8
# upenn_0726_Piano_2_2      5cb6025b-6cd8-4a31-9611-02f5d7260ace
# nus_cpr_11_2              03167c74-f240-488c-bc6c-39ea803ec943
# iiith_cooking_117_4       49944f64-4fc9-44b8-bba2-7d6720c3186f
# cmu_bike17_3              2cc1db50-e1ca-4bc5-9066-4adc98b27df4
# fair_bike_06_16           b2a184be-1b3c-4e0e-b297-d2a3a95e3e43
# iiith_guitar_002_6        a3cfad7c-b099-4729-b168-fff85dfe5a32
# fair_bike_06_7            6835b48d-ce8e-474d-b589-86d023628792
# georgiatech_bike_01_8     c0693544-bedc-4b92-8d2a-42acde8a9cf0
# iiith_cooking_111_2       eba56e4f-7ec8-4d47-9380-e69928323e94
# iiith_guitar_002_8        fdfe951c-8388-4228-9b6f-7fad2b34b4f8
# fair_bike_06_10           91bb7bcf-7498-4611-a3bd-41869be84ef8
# upenn_0722_Piano_2_2      46deacb7-2d19-4b18-b440-170f9ea7f28a
# georgiatech_covid_12_5    4d250ada-e17a-4385-a08c-88b645cfe872
# upenn_0407_Guitar_1_5     4641c429-4150-415c-a824-bf42a22d1dbf
# upenn_0722_Piano_2_4      fa1b7aec-f252-42c7-b362-443f11e87fdf
# indiana_bike_06_7         65aab74f-39c0-4f9f-9661-a3298d18c4b0
# cmu_bike02_3              2e7ebb31-80dd-474e-97d7-4ce508299297
# sfu_covid_001_2           c0a2159b-e900-4fe1-ac09-7a85925ef216
# georgiatech_covid_12_11   d6706cac-3a65-411f-b9e2-cf7245305fbe
# iiith_piano_001_6         a491cdbc-d733-4d26-a34d-cc5aef734b33
# georgiatech_covid_12_13   ea9149f5-4953-4f44-9712-e45ccb976568
# cmu_bike13_2              2d60dbfc-61dd-468b-b30a-c63b9d29c9bb
# georgiatech_covid_13_6    87531064-1b80-40c5-896c-344cb3200d5a
# fair_bike_01_6            aa27937e-3751-4746-ab72-7f58a46b1c96
# nus_cooking_07_4          10114022-4de6-43cd-af19-b3bc5cbeae31
# georgiatech_covid_12_7    574adb34-f42d-494b-8ccf-a62922bb5299
# utokyo_pcr_2001_36_4      eea5372d-3def-442b-9f3a-2b72f2d701fb
# fair_bike_01_4            de3728ca-fdeb-4591-80ab-cb2b32182a50
# cmu_bike02_4              80ad3fed-5d6d-4d0a-b160-b0ce4d06ab81
# upenn_0331_Guitar_4_2     304ae780-7eb3-4665-8b34-c8558dbc0610
# fair_bike_09_2            3d41b047-b3c7-43b0-8663-daddc3e7d32c
# indiana_music_11_3        f5a0a29d-affb-41d9-af1e-42ae7d1d198b
# georgiatech_covid_07_12   0f9842a7-512f-4c04-9254-b810129f52b3
# fair_bike_06_3            17fc7017-4b64-4adb-b55f-10ca76476366
# georgiatech_bike_02_2     2f7b4f03-02fa-4d45-a686-0aa9f1dfd00a
# upenn_0331_Guitar_4_5     5dad1edc-bcaa-4ad3-b091-cd9b01917f47
# upenn_0407_Violin_1_5     03672458-fd03-4e1e-9754-776175089ab0
# cmu_bike19_2              dd77aa6d-cbf6-4883-9bc5-bd6d7e0dcf91
# iiith_cooking_116_2       39d5e4c4-993f-46ad-979b-3daa146e4d53
# indiana_music_11_2        fbc64b70-2224-4028-a008-2185b2afc200
# indiana_music_09_3        e9a2e67e-7076-4e59-8001-bad5ff3bdd5f
# iiith_piano_001_8         cc5069d5-bcb4-49d6-b2cb-b43732ed7925
# fair_bike_01_11           448f59b5-2f28-4013-a96a-6f3fa5bb2252
# indiana_bike_06_10        e060eefb-7e9e-4304-a73e-e8d04694c9f6
# iiith_cooking_44_1        01b0a6e3-04ce-4f0d-8df4-b3d3c1508780
# fair_bike_06_6            b9519252-bc68-4d3f-9781-81426234e671
# iiith_cooking_40_1        ed064e3d-b2e1-4103-b955-3d720460d89b
# utokyo_pcr_2001_38_8      8c437105-67f4-43eb-a4ee-ef1a848074a7
# fair_bike_01_14           ba46c08b-3b5a-46f2-b77d-4a296f45c042
# fair_bike_02_8            9105418d-9a1b-445b-a77e-108d22530a8c
# fair_bike_07_19           aceb9ba2-bcd0-4249-baaf-12cd03e14aaa
# utokyo_pcr_2001_35_4      0fc077f4-37e0-45a0-902a-d72bc3a9ac0f
# iiith_cooking_77_2        f1c3d2f5-e6bf-4899-a40d-12489d1ebb11
# cmu_bike14_4              76311964-abcc-4d73-b84b-241e9c782850
# fair_bike_07_14           b4b83178-90f5-4ca8-9862-224d5044b0c4
# fair_bike_07_3            1ec6c280-a6df-4666-87ef-9da5a57e2925
# fair_bike_01_16           d9ce9305-d24f-4127-9d6d-e4d89e43f44b
# georgiatech_covid_05_12   c7c5fe65-f694-4ff1-b51d-ee8059143f51
# fair_bike_07_4            93dee400-712b-4491-9d4a-7b4bf21f4f92
# sfu_covid_001_10          3a7779b2-5d99-46b2-a0c0-28fc2100918e
# fair_bike_07_18           7b078956-9843-49dd-be3c-39591bde70fe
# upenn_0719_Piano_2_2      6abf4872-3bc1-4e63-8fb6-90f796505e31
# upenn_0407_Violin_1_2     1c000f43-c516-4552-8010-9055a49763d1
# fair_bike_06_15           d03179da-1fd6-40f1-9ed2-8c2681ca2a0c
# upenn_0728_Guitar_1_2     0de804e8-619a-4e39-8dfb-e1244898c6cd
# upenn_0719_Piano_2_3      aa461c0c-d577-4667-b3df-157207b11063
# nus_cpr_24_2              46018fc1-21a0-4c62-b009-ad420b731686
# georgiatech_bike_05_7     260afb8c-0cac-4f5e-8b07-02e85fc17d6f
# upenn_0717_Piano_1_3      7014a547-6f84-48cb-bc91-28012c4cce06
# sfu_covid_005_2           b63da48d-f6a2-4b94-a9af-3e694ca549f2
# cmu_bike03_2              3c99493b-a76f-4934-b444-c8dcb68b17d3
# georgiatech_covid_03_12   c0049eef-6fb3-4383-9ab3-5e6b892cd843
# cmu_bike03_3              df02e9d2-edcd-4015-829a-81cb6067d6fa
# upenn_0724_Piano_1_3      804797fc-ccdb-4478-9916-1e8949fbd25c
# upenn_0701_Piano_2_2      cac56c11-1de1-476f-a05d-f43c0cf99893
# georgiatech_bike_11_7     864227f5-9937-4e42-894e-b96e59ad5e31
# sfu_covid_001_4           2bb5ab9f-0fa9-4eeb-b550-9b7a9bffe3ee
# georgiatech_covid_03_10   e4751da9-508b-401f-bdcb-90bb0921d7b9
# nus_covidtest_22_2        5dc6b68f-c360-4519-8b45-1d9ba21dbeed
# georgiatech_bike_11_2     7d2a3fcc-a2b1-452b-923d-e819a9e8c84f
# nus_cooking_06_4          4a10d608-6712-4f08-aa69-1cfd4541dd6c
# upenn_0721_Piano_2_3      e5beffc8-2cc5-4cc5-9e0e-b22b843aaa4c
# iiith_cooking_123_4       3382c19f-4a93-4247-9a7c-11f4f72959a0
# georgiatech_covid_16_6    713cffc9-4d72-416c-a038-e1fe258b0468
# utokyo_pcr_2001_38_4      18b03995-c3b2-432b-8dc9-159cd183991a
# iiith_cooking_81_2        7f57b437-75b9-4cff-a260-28dba2ffaacd
# upenn_0331_Guitar_2_3     f78ea88a-550b-493d-aa10-4898f7bb987c
# georgiatech_bike_09_6     5fa21441-f369-4773-b284-9cae3a722278
# fair_bike_07_8            c30c1104-b238-4dcf-891b-1160ede92723
# indiana_bike_06_8         3c398830-aeb7-4795-8191-36dd3ee840b1
# georgiatech_bike_05_2     72784203-1894-492b-b97d-3854eceae191
# cmu_bike18_3              e929ea2f-f2a6-4823-a201-5810f976c963
# fair_bike_02_7            0d7dc221-d9dd-401a-acb8-b6e76e458300
# indiana_bike_06_2         3586d05f-91db-4a07-b326-77c4ecd44509
# iiith_cooking_111_4       83167883-277a-4720-accb-4aeb0253e60e
# upenn_0718_Violin_2_5     794b3bd3-eac9-4d0d-9789-bd068bff3944
# iiith_cooking_128_4       c112d4da-5120-47d7-9b05-a4ef68baa226
# upenn_0706_Guitar_2_2     55a996a2-cdf3-4976-b475-a7c4c6a008a8
# iiith_cooking_118_2       a6c76788-37ca-4005-9e7e-cf5ecb00d8cf
# iiith_guitar_002_10       3d4f5b74-c8da-4de9-a506-b09978baf754
# upenn_0407_Violin_2_5     19df5a1f-ff4f-427d-9f9a-61f001512a19
# fair_bike_06_8            b7c782b1-9688-4b19-8f88-003fed1d0e61
# iiith_cooking_84_4        8c6578a1-4f98-4bdb-861e-64b321b32c9f
# georgiatech_bike_01_2     e7192f4a-1559-409e-9628-34fde0504bee
# iiith_cooking_45_3        fa0e1a71-2174-43ef-a694-a4af360573a4
# georgiatech_covid_12_9    80f65504-a37a-4c84-8a19-df3bba123326
# iiith_cooking_45_1        abcd9473-0885-43cc-9e4e-f632f36871d2
# upenn_0717_Piano_1_2      354f076e-079f-440d-bd38-97ddfcd19002
# upenn_0721_Piano_2_2      a8d04142-fc0b-4ad4-acaa-8c17424411ff
# georgiatech_covid_09_4    dd09ac20-b7ae-48e0-a0c1-69f49f541ac4
# iiith_cooking_131_4       ee2c4d41-d7f7-4b85-9f4f-cc1da654cd40
# cmu_bike14_3              be3ba254-9db0-4fa9-91ed-c9e7117f8d83
# upenn_0407_Guitar_1_3     4ad70302-a794-40ae-ba8f-248296fb2809
# georgiatech_bike_19_8     413c69e1-0d01-4fce-87fd-eae9e152c754
# cmu_bike08_5              7dbdb2ef-939a-44a8-a0ee-92f36cc7428b
# fair_bike_06_18           e6bbb6dc-94c1-4e80-9e46-2b25f40e0c1c
# fair_bike_06_19           9aca257b-e95d-45b1-aa6b-e2abfb400fa4
# indiana_music_12_4        65ec76ec-8ad8-452f-8d65-23e7cd7bf224
# georgiatech_covid_13_10   6a3376a7-949e-4385-b16e-076dfb8c3f5a
# fair_cooking_08_6         5d4abe32-590d-470d-8fd1-4585833afaad
# upenn_0317_Violin_3_8     91718808-e351-4df2-be6c-8cf2a07384e3

# %%
vis_take_name = "upenn_0717_Piano_1_2" # MODIFY

# Get selected take's annotation
vis_take_anno = gt_anno[take_to_uid[vis_take_name]]
print(f"Found {len(vis_take_anno)} images from {vis_take_name} with annotated frame number:")
# Print all annotated frames
print(list(vis_take_anno.keys()))

# Load aria cam name and cam pose
take = [t for t in takes if t['take_name'] == vis_take_name][0]
aria_name = get_ego_aria_cam_name(take)
curr_uid = take_to_uid[vis_take_name]
curr_cam_pose = json.load(open(os.path.join(cam_pose_dir, f"{curr_uid}.json")))
# Out:
# Found 298 images from upenn_0717_Piano_1_2 with annotated frame number:
# ['102', '105', '108', '111', '114', '117', '120', '123', '126', '129', '132', '135', '141', '144', '147', '150', '153', '156', '159', '162', '165', '168', '171', '174', '177', '180', '183', '186', '189', '192', '195', '198', '201', '204', '207', '210', '213', '216', '219', '222', '225', '228', '234', '237', '240', '243', '246', '249', '252', '255', '258', '261', '264', '267', '270', '273', '276', '279', '282', '285', '291', '294', '297', '300', '303', '306', '309', '312', '315', '318', '321', '324', '327', '330', '333', '336', '339', '342', '345', '348', '351', '354', '357', '360', '363', '366', '369', '372', '375', '378', '381', '384', '387', '390', '393', '396', '399', '402', '405', '408', '411', '414', '417', '420', '423', '426', '429', '432', '435', '438', '441', '444', '447', '450', '456', '459', '462', '465', '468', '471', '474', '477', '480', '483', '486', '489', '492', '495', '498', '501', '504', '507', '510', '513', '516', '519', '522', '525', '528', '532', '535', '538', '541', '544', '547', '550', '553', '556', '559', '562', '565', '568', '571', '574', '577', '580', '583', '586', '589', '592', '595', '598', '601', '604', '607', '610', '613', '616', '619', '622', '625', '628', '631', '634', '637', '640', '643', '646', '649', '652', '655', '658', '661', '664', '667', '670', '673', '676', '682', '685', '688', '691', '694', '697', '700', '735', '738', '741', '744', '747', '750', '753', '810', '813', '816', '819', '822', '825', '828', '831', '834', '837', '840', '843', '846', '849', '1046', '1049', '1052', '1055', '1058', '1061', '1064', '1150', '1153', '1156', '1159', '1162', '1165', '1168', '1171', '1174', '1177', '1180', '1183', '1186', '1313', '1316', '1319', '1322', '1325', '1328', '1331', '1334', '1337', '1340', '1343', '1346', '1349', '1352', '1355', '1358', '1361', '1364', '1367', '1370', '1373', '1376', '1379', '1382', '1385', '1388', '1391', '1394', '1397', '1400', '1403', '1406', '1409', '1412', '1415', '1418', '1421', '1424', '1427', '1430', '1433', '1436', '1439', '1442', '1445', '1448', '1451', '1454', '1457', '1460', '1463', '1466', '1469', '1472', '1475', '1478', '1481', '1484', '1487', '1490', '1493', '1496']

# %% [markdown]
# #### Select frame_idx and visualize
#
# Pick one annotated frame and visualize 2D annotation, 3D annotation and projected 2D annotation.

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
vis_frame_idx = 547 # MODIFY
vis_frame_idx = str(vis_frame_idx)

# Image
img = np.array(Image.open(os.path.join(img_dir, vis_take_name, f"{int(vis_frame_idx):06d}.jpg")))

## hand bounding box visualization
bbox_right = np.array(vis_take_anno[vis_frame_idx]['right_hand_bbox']).astype(np.float32)
bbox_left = np.array(vis_take_anno[vis_frame_idx]['left_hand_bbox']).astype(np.float32)
two_hands_bbox = {"right": bbox_right, "left": bbox_left}
vis_2d_bbox(img, two_hands_bbox, vis_take_name, vis_frame_idx, "bbox")

## 2D annotation visualization
kpts_2d_right = np.array(vis_take_anno[vis_frame_idx]['right_hand_2d']).astype(np.float32)
kpts_2d_left = np.array(vis_take_anno[vis_frame_idx]['left_hand_2d']).astype(np.float32)
two_hands_kpts_2d = {"right": kpts_2d_right, "left": kpts_2d_left}
vis_2d_hand_pose(img, two_hands_kpts_2d, vis_take_name, vis_frame_idx, "2D GT")

## 3D annotation visualization
kpts_3d_right = np.array(vis_take_anno[vis_frame_idx]['right_hand_3d']).astype(np.float32)
kpts_3d_left = np.array(vis_take_anno[vis_frame_idx]['left_hand_3d']).astype(np.float32)
# rotate 3D annotations if in portrait view
if orientation == "portrait":
    print(kpts_3d_right.shape)
    R = np.array([[0,-1,0], [1,0,0], [0,0,1]])
    print(R)
    kpts_3d_right = (R @ kpts_3d_right.T).T
    kpts_3d_left = (R @ kpts_3d_left.T).T
two_hands_kpts_3d = {"right": kpts_3d_right, "left": kpts_3d_left}
vis_3d_hand_pose(two_hands_kpts_3d)

## Projected 2D annotation visualization
intrinsics = np.array(curr_cam_pose[aria_name]["camera_intrinsics"]).astype(np.float32)
kpts_2d_right_proj = cam_to_img(kpts_3d_right, intrinsics) if len(kpts_3d_right) > 0 else kpts_3d_right
kpts_2d_left_proj = cam_to_img(kpts_3d_left, intrinsics) if len(kpts_3d_left) > 0 else kpts_3d_left
two_hands_kpts_2d_proj = {"right": kpts_2d_right_proj, "left": kpts_2d_left_proj}
vis_2d_hand_pose(img, two_hands_kpts_2d_proj, vis_take_name, vis_frame_idx, "Projected 3D GT")
# Out:
# (21, 3)
# [[ 0 -1  0]
#  [ 1  0  0]
#  [ 0  0  1]]
